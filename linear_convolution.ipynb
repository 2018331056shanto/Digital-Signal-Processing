# %% [markdown]
# #Compute linear convolution of two signals
# ## **Reg :2018331056**
#
# ## Convolution
#
# ####Convolution is a mathematical operation used to express the relation between input and output of an LTI system.
#
# ![Screenshot from 2022-08-09 16-31-44.png](data:image/png;base64,...)
#
# ####The process of computing the convolution between x(k) and h(k) involves the following four steps.
#
#  **Folding**. Fold h(k) about k = 0 to obtain h(−k).
# -----
#  **Shifting**. Shift h(−k) by n0 to the right (left) if n0 is positive (negative), to obtain h(n0 − k).
#  ---------
#  **Multiplication**. Multiply x(k) by h(n0 − k) to obtain the product sequence vn0 (k) ≡ x(k)h(n0 − k).
# --------
#  **Summation**. Sum all the values of the product sequence vn0 (k) to obtain the value of the output at time n = n0 .
# -----------

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Input Signal && Impulse Response

# %%
x=[1,2,3,1] #input signal
h=[1,2,1,-1] #impulse response
# plt.plot(x,h)
n=np.arange(-10,10)
inputSamples=np.zeros(n.shape)
idx=0;
for i in range(10,10+len(x),1):
  inputSamples[i]=x[idx]
  idx+=1
# print(inputSamples)

# print(input)
# plt.plot(input)
plt.figure(figsize=(20,10))
plt.subplot(221)
plt.title("Input Signal x(n)")
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.xticks(n)
plt.stem(n,inputSamples)
plt.show()

n=np.arange(-10,10)
impulseSamples=np.zeros(n.shape)
idx=0;
for i in range(9,9+len(h),1):
  impulseSamples[i]=h[idx]
  idx+=1
# print(impulseSamples)

# print(input)
# plt.plot(input)
plt.figure(figsize=(20,10))
plt.subplot(221)
plt.title("Impulse Response h(n)")
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.xticks(n)
plt.stem(n,impulseSamples)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:20: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:39: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %% [markdown]
# ## Floding the Impulse Response

# %%
#folding
temp=h[::-1]
# print(temp)
foldImpulseResponse=np.zeros(n.shape)
idx=0
for i in range(9,9+len(h),1):
  foldImpulseResponse[i]=temp[idx]
  idx+=1
foldImpulseResponse=np.roll(foldImpulseResponse,-1)
plt.figure(figsize=(20,10))
plt.subplot(221)
plt.title("Impulse Response h(-n)")
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.xticks(n)
plt.stem(n,foldImpulseResponse)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()

# %% [markdown]
# ## Multiplication and Summation

# %%
#multiplication

impulse=np.zeros(n.shape)
multilyWithImpulse=np.zeros(n.shape)
impulse=foldImpulseResponse
ans=[]
# print(foldImpulseResponse)
# print(impulse)
for i in range(-1,5,1):
  # print(i)
  impulse=np.roll(foldImpulseResponse,i)
  # print(impulse)
  plt.figure(figsize=(20,10))
  plt.subplot(221)
  st="impulse response h(-n ) "+str(i);
  # print(st)
  plt.title(st)
  plt.xlabel("Samples")
  plt.ylabel("Amplitude")
  plt.xticks(n)
  plt.stem(n,impulse)
  plt.show()

  multilyWithImpulse=np.multiply(impulse,inputSamples)
  #Summation
  ans.append(np.sum(multilyWithImpulse))
  plt.figure(figsize=(20,10))
  plt.subplot(221)
  st="Multiplication h(-n ) "+str(i);
  # print(st)
  plt.title(st)
  plt.xlabel("Samples")
  plt.ylabel("Amplitude")
  plt.xticks(n)
  plt.stem(n,multilyWithImpulse)
  plt.show()


print("Convolution of Two signal x(n) and h(n) :",ans)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
# ...

# %% [markdown]
# ## Final Output Signal

# %%
finalAns=np.zeros(n.shape)
idx=0
for i in range(9,8+len(ans),1):
  finalAns[i]=ans[idx]
  idx+=1

plt.figure(figsize=(20,10))
plt.subplot(221)
st="Linear Convolution";
# print(st)
plt.title(st)
plt.xlabel("Samples")
plt.ylabel("Amplitude")
plt.yticks(n)
plt.xticks(n)
plt.stem(n,finalAns)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   app.launch_new_instance()
